# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:\Users\HP\OneDrive\Documents\avg_transaction.csv")
df.head()
# Out:
#   campaign_date  control_group_avg_tran  test_group_avg_tran
# 0    10-09-2023                  251.02               401.78
# 1    11-09-2023                  250.77               326.16
# 2    12-09-2023                  248.81               303.92
# 3    13-09-2023                  255.90               363.29
# 4    14-09-2023                  255.86               317.06

# %%
df = pd.read_csv("C:\Users\HP\OneDrive\Documents\credit_profiles.csv")
df.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df = pd.read_csv("C:\Users\HP\OneDrive\Documents\customers.csv")
df.head()
# Out:
#    cust_id          name  gender  age location      occupation  annual_income  \
# 0        1  Dhruv Bansal  Female    2     City  Business Owner       358211.0
# 1        2  Kabir Thakur  Female   47     City      Consultant        65172.0
# 2        3  Kriti Mangal    Male   21     City      Freelancer        22378.0
# 3        4  Sara Dwivedi    Male   24    Rural      Freelancer        33563.0
# 4        5   Aarohi Negi    Male   48     City      Consultant        39406.0
#
#   marital_status
# 0        Married
# 1         Single
# 2        Married
# 3        Married
# 4        Married

# %%
import mysql.connector
import pandas as pd   

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='root',
    database='e_master_card'
)

df_cust = pd.read_sql("SELECT * FROM customers", conn)
df_cust.head(3)
# Out:
#    cust_id          name  gender  age location      occupation  annual_income  \
# 0        1  Dhruv Bansal  Female    2     City  Business Owner       358211.0
# 1        2  Kabir Thakur  Female   47     City      Consultant        65172.0
# 2        3  Kriti Mangal    Male   21     City      Freelancer        22378.0
#
#   marital_status
# 0        Married
# 1         Single
# 2        Married

# %%
df_trans = pd.read_sql("SELECT * FROM transactions", conn)
df_trans.head(3)
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe

# %%
df_cs = pd.read_sql("SELECT * FROM credit_profiles", conn)
df_cs.head(3)
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0

# %%
# when you are done importing the data, close the connection
conn.close()

# %%
print("Customers data",df_cust.shape)
print("Credit Score data",df_cs.shape)
print("Transactions data",df_trans.shape)
# Out:
# Customers data (1000, 8)
# Credit Score data (1004, 6)
# Transactions data (500000, 7)

# %%
df_cust.head()
# Out:
#    cust_id          name  gender  age location      occupation  annual_income  \
# 0        1  Dhruv Bansal  Female    2     City  Business Owner       358211.0
# 1        2  Kabir Thakur  Female   47     City      Consultant        65172.0
# 2        3  Kriti Mangal    Male   21     City      Freelancer        22378.0
# 3        4  Sara Dwivedi    Male   24    Rural      Freelancer        33563.0
# 4        5   Aarohi Negi    Male   48     City      Consultant        39406.0
#
#   marital_status
# 0        Married
# 1         Single
# 2        Married
# 3        Married
# 4        Married

# %%
df_trans.head()
# Out:
#    tran_id  cust_id   tran_date  tran_amount  platform   product_category  \
# 0        1      705  2023-01-01           63  Flipkart        Electronics
# 1        2      385  2023-01-01           99   Alibaba  Fashion & Apparel
# 2        3      924  2023-01-01          471   Shopify             Sports
# 3        4      797  2023-01-01           33   Shopify  Fashion & Apparel
# 4        5      482  2023-01-01           68    Amazon  Fashion & Apparel
#
#   payment_type
# 0      Phonepe
# 1  Credit Card
# 2      Phonepe
# 3         Gpay
# 4  Net Banking

# %%
df_cs.head()
# Out:
#    cust_id  credit_score  credit_utilisation  outstanding_debt  \
# 0        1           749            0.585171           19571.0
# 1        2           587            0.107928          161644.0
# 2        3           544            0.854807             513.0
# 3        4           504            0.336938             224.0
# 4        5           708            0.586151           18090.0
#
#    credit_inquiries_last_6_months  credit_limit
# 0                             0.0       40000.0
# 1                             2.0        1250.0
# 2                             4.0        1000.0
# 3                             2.0        1000.0
# 4                             2.0       40000.0

# %%
df_cust.head(3)
# Out:
#    cust_id          name  gender  age location      occupation  annual_income  \
# 0        1  Dhruv Bansal  Female    2     City  Business Owner       358211.0
# 1        2  Kabir Thakur  Female   47     City      Consultant        65172.0
# 2        3  Kriti Mangal    Male   21     City      Freelancer        22378.0
#
#   marital_status
# 0        Married
# 1         Single
# 2        Married

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000     950.000000
# mean    500.500000    36.405000  139410.314737
# std     288.819436    15.666155  112416.802007
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   47627.500000
# 50%     500.500000    32.000000  112218.500000
# 75%     750.250000    46.000000  193137.500000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust.isnull().sum()
# Out:
# cust_id            0
# name               0
# gender             0
# age                0
# location           0
# occupation         0
# annual_income     50
# marital_status     0
# dtype: int64

# %%
df_cust[df_cust.annual_income.isna()].head(4)
# Out:
#      cust_id             name  gender  age location      occupation  \
# 14        15       Isha Arora  Female   25    Rural          Artist
# 82        83  Sanjana Singhal    Male   27     City      Freelancer
# 97        98        Sia Batra    Male   47   Suburb  Business Owner
# 102      103    Pooja Ganguly    Male   32     City  Data Scientist
#
#      annual_income marital_status
# 14             NaN        Married
# 82             NaN         Single
# 97             NaN        Married
# 102            NaN        Married

# %%
df_cust[df_cust.occupation=="Artist"].annual_income.median()
# Out:
# np.float64(45794.0)

# %%
occupation_wise_inc_median = df_cust.groupby("occupation")["annual_income"].median()
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
def get_median_val(row):
    if pd.isnull(row["annual_income"]):
        return occupation_wise_inc_median[row["occupation"]]
    else:
        return row["annual_income"]

# %%
get_median_val({"cust_id":3245, "occupation":"Artist", "annual_income":678})
# Out:
# 678

# %%
df_cust['annual_income'] = df_cust.apply(
    lambda row: occupation_wise_inc_median[row['occupation']] if pd.isnull(row['annual_income']) else row['annual_income'],
    axis=1
# Out:
#   Cell In[24], line 3
#     axis=1
#           ^
# SyntaxError: incomplete input

# %%
occupation_wise_inc_median['Artist']
##%%
# 2. Replace null values in annual_income with the median income of their occupation group
df_cust['annual_income'] = df_cust.apply(
    lambda row: occupation_wise_inc_median[row['occupation']] if pd.isnull(row['annual_income']) else row['annual_income'],
    axis=1
)

# %%
df_cust.iloc[[14,22,82]]
# Out:
#     cust_id             name  gender  age location  occupation  annual_income  \
# 14       15       Isha Arora  Female   25    Rural      Artist        45794.0
# 22       23      Swara Pawar    Male   19     City  Freelancer        36863.0
# 82       83  Sanjana Singhal    Male   27     City  Freelancer        46759.0
#
#    marital_status
# 14        Married
# 22        Married
# 82         Single

# %%
plt.figure(figsize=(5, 5))
sns.histplot(df_cust['annual_income'], kde=True, color='red', label='Data')
plt.title('Histogram of annual_income')
plt.show()

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    36.405000  138916.765500
# std     288.819436    15.666155  110969.408643
# min       1.000000     1.000000       2.000000
# 25%     250.750000    26.000000   48229.500000
# 50%     500.500000    32.000000  113416.000000
# 75%     750.250000    46.000000  192614.000000
# max    1000.000000   135.000000  449346.000000

# %%
df_cust[df_cust.annual_income<100]
# Out:
#      cust_id             name  gender  age location           occupation  \
# 31        32     Veer Gambhir    Male   50     City       Business Owner
# 262      263      Veer Rathod    Male   53   Suburb       Business Owner
# 316      317  Avinash Chauhan    Male   47     City           Consultant
# 333      334  Samaira D'Souza  Female   29     City       Data Scientist
# 340      341    Ridhi Rastogi  Female   33    Rural  Fullstack Developer
# 543      544      Gauri Gupta    Male   54     City           Consultant
# 592      593     Vivaan Pande  Female   32     City       Business Owner
# 633      634   Aradhya Pandey    Male   26     City       Data Scientist
# 686      687      Gauri Nanda    Male   40     City       Business Owner
# 696      697    Avani Lalwani    Male   47     City           Consultant
#
#      annual_income marital_status
# 31            50.0        Married
# 262           50.0        Married
# 316           50.0        Married
# 333           50.0        Married
# 340           50.0        Married
# 543            2.0        Married
# 592           50.0        Married
# 633            2.0        Married
# 686            2.0        Married
# 696           20.0        Married

# %%
occupation_wise_inc_median
# Out:
# occupation
# Accountant              65265.0
# Artist                  45794.0
# Business Owner         261191.5
# Consultant              58017.0
# Data Scientist         135759.0
# Freelancer              46759.0
# Fullstack Developer     76774.0
# Name: annual_income, dtype: float64

# %%
for index, row in df_cust.iterrows():
    if row["annual_income"] < 100:
        occupation = df_cust.at[index, "occupation"]
        df_cust.at[index, "annual_income"] = occupation_wise_inc_median[occupation]

# %%
df_cust[df_cust.annual_income<100]
# Out:
# Empty DataFrame
# Columns: [cust_id, name, gender, age, location, occupation, annual_income, marital_status]
# Index: []

# %%
df_cust.loc[[31,256]]
# Out:
#      cust_id          name gender  age location      occupation  \
# 31        32  Veer Gambhir   Male   50     City  Business Owner
# 256      257  Avinash Jain   Male   28     City      Freelancer
#
#      annual_income marital_status
# 31        261191.5        Married
# 256       205791.0        Married

# %%
##data visualization##

# %%
avg_income_per_occupation  = df_cust.groupby("occupation")["annual_income"].mean()
avg_income_per_occupation
# Out:
# occupation
# Accountant              64123.562500
# Artist                  45309.236842
# Business Owner         268447.368512
# Consultant              60703.154639
# Data Scientist         137021.266304
# Freelancer              76327.508772
# Fullstack Developer     78727.972973
# Name: annual_income, dtype: float64

# %%
avg_income_per_occupation.index
# Out:
# Index(['Accountant', 'Artist', 'Business Owner', 'Consultant',
#        'Data Scientist', 'Freelancer', 'Fullstack Developer'],
#       dtype='object', name='occupation')

# %%
avg_income_per_occupation.values
# Out:
# array([ 64123.5625    ,  45309.23684211, 268447.36851211,  60703.15463918,
#        137021.26630435,  76327.50877193,  78727.97297297])

# %%
sns.barplot(x=avg_income_per_occupation.index, y=avg_income_per_occupation.values, palette="rocket")
plt.title('Average Annual Income Per Occupation')
plt.xlabel('Occupation')
plt.ylabel('Average Annual Income ($)')
plt.xticks(rotation=45)
plt.show()

# %%
##beautification

# %%
categorical_columns = ["gender", "location", "occupation", "marital_status"]
for col in categorical_columns:
# Loop through each categorical column and plot a bar chart of average annual income
    plt.figure(figsize=(8, 4))
    avg_income_per_group = df_cust.groupby(col)['annual_income'].mean().sort_values()
    sns.barplot(x=avg_income_per_group.index, y=avg_income_per_group.values, palette="Paired")
    plt.xticks(rotation=45)
    plt.title(f'Average Annual Income Per {col.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel('Average Annual Income ($)')
    plt.show()

# %%
# List of categorical columns
cat_cols = ['gender', 'location', 'occupation', 'marital_status']

num_rows = 3
# Create subplots
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 4 * num_rows))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

# Create subplots for each categorical column
for i, cat_col in enumerate(cat_cols):
    # Calculate the average annual income for each category
    avg_income_by_category = df_cust.groupby(cat_col)['annual_income'].mean().reset_index()
    
    # Sort the data by 'annual_income' before plotting
    sorted_data = avg_income_by_category.sort_values(by='annual_income', ascending=False)
    
    sns.barplot(x=cat_col, y='annual_income', data=sorted_data, ci=None, ax=axes[i], palette='tab10')
    axes[i].set_title(f'Average Annual Income by {cat_col}')
    axes[i].set_xlabel(cat_col)
    axes[i].set_ylabel('Average Annual Income')
    # Rotate x-axis labels for better readability
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

# Hide any unused subplots
for i in range(len(cat_cols), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %%
#Analyze Age Column

# %% [markdown]
# **Handle Null Values: Age Column**

# %%
#First let us check if there are any NULL values in the Age column

# %%
df_cust.age.isnull().sum()
# Out:
# np.int64(0)

# %%
df_cust.age.describe()
# Out:
# count    1000.000000
# mean       36.405000
# std        15.666155
# min         1.000000
# 25%        26.000000
# 50%        32.000000
# 75%        46.000000
# max       135.000000
# Name: age, dtype: float64

# %%
plt.hist(df_cust.age, bins=20, edgecolor= "Green")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
outliers = df_cust[(df_cust.age>50)|(df_cust.age>80)]
outliers
# Out:
#      cust_id              name  gender  age location           occupation  \
# 21        22       Aarohi Jain    Male   59     City       Business Owner
# 26        27  Aradhya Banerjee  Female   64     City       Business Owner
# 37        38       Amara Kadam    Male   64     City       Business Owner
# 40        41       Neha Duggal    Male   62   Suburb       Business Owner
# 41        42      Manya Thakur    Male  110     City               Artist
# ..       ...               ...     ...  ...      ...                  ...
# 969      970       Vivaan Shah    Male   55   Suburb       Business Owner
# 987      988   Ritvik Kulkarni    Male   59     City       Business Owner
# 989      990       Avani Pande    Male   55     City       Business Owner
# 991      992  Krishna Banerjee    Male  135     City  Fullstack Developer
# 996      997    Sia Chatterjee    Male   55     City       Business Owner
#
#      annual_income marital_status
# 21        435536.0        Married
# 26        360483.0        Married
# 37        115498.0        Married
# 40        327569.0        Married
# 41          7621.0        Married
# ..             ...            ...
# 969       263055.0        Married
# 987       303101.0        Married
# 989       239619.0        Married
# 991        93267.0         Single
# 996       290061.0         Single
#
# [169 rows x 8 columns]

# %%
df_cust.age.median()
# Out:
# np.float64(32.0)

# %%
median_age_per_occupation = df_cust.groupby("occupation")["age"].median()
median_age_per_occupation
# Out:
# occupation
# Accountant             31.5
# Artist                 26.0
# Business Owner         51.0
# Consultant             46.0
# Data Scientist         32.0
# Freelancer             24.0
# Fullstack Developer    27.5
# Name: age, dtype: float64

# %%
for index, row  in outliers.iterrows():
    df_cust.at[index,"age"] = median_age_per_occupation[row["occupation"]]

# %%
df_cust[(df_cust.age>50)|(df_cust.age>80)]
# Out:
#      cust_id              name  gender   age location      occupation  \
# 21        22       Aarohi Jain    Male  51.0     City  Business Owner
# 26        27  Aradhya Banerjee  Female  51.0     City  Business Owner
# 37        38       Amara Kadam    Male  51.0     City  Business Owner
# 40        41       Neha Duggal    Male  51.0   Suburb  Business Owner
# 52        53     Aahana Khanna    Male  51.0   Suburb  Business Owner
# ..       ...               ...     ...   ...      ...             ...
# 968      969       Ishan Mehta    Male  51.0   Suburb  Business Owner
# 969      970       Vivaan Shah    Male  51.0   Suburb  Business Owner
# 987      988   Ritvik Kulkarni    Male  51.0     City  Business Owner
# 989      990       Avani Pande    Male  51.0     City  Business Owner
# 996      997    Sia Chatterjee    Male  51.0     City  Business Owner
#
#      annual_income marital_status
# 21        435536.0        Married
# 26        360483.0        Married
# 37        115498.0        Married
# 40        327569.0        Married
# 52        446205.0         Single
# ..             ...            ...
# 968       287627.0        Married
# 969       263055.0        Married
# 987       303101.0        Married
# 989       239619.0        Married
# 996       290061.0         Single
#
# [145 rows x 8 columns]

# %%
df_cust.describe()
# Out:
#            cust_id          age  annual_income
# count  1000.000000  1000.000000    1000.000000
# mean    500.500000    34.275500  140483.548500
# std     288.819436    10.806323  110463.002934
# min       1.000000     1.000000    5175.000000
# 25%     250.750000    25.000000   49620.500000
# 50%     500.500000    32.000000  115328.000000
# 75%     750.250000    44.000000  195514.250000
# max    1000.000000    51.000000  449346.000000
